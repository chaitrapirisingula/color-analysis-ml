# %%
# Chaitra Pirisingula
# Shruti Pradeep
# 04/10/2023

# %%
from ColorBlindnessAnalysis import *
from ColorMasks import *
import cv2

# %%
cb_masks = [protanopia_simulation_matrix, deuteranopia_simulation_matrix, tritanopia_simulation_matrix]
cb_names = ["Protanopia", "Deuteranopia", "Tritanopia"]

# %%
# Load the image
img = cv2.imread('images/rainbow_hair.png')

recolored_protanopia = improve_contrast_red_green(img)
recolored_tritanopia = improve_contrast_red_green(img)

protanopia_image = simulate_colorblindness(protanopia_simulation_matrix, recolored_protanopia)
protanopia_colors = get_colors(protanopia_image, 20, "Recolored " + cb_names[0])

tritanopia_image = simulate_colorblindness(tritanopia_simulation_matrix, recolored_tritanopia)
tritanopia_colors = get_colors(tritanopia_image, 20, "Recolored " + cb_names[2])

# %%
# Load image
image = cv2.imread('images/user.png')

# %%
# Display original image with color scheme
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
original_colors = get_colors(image_rgb, 20, "Original")

# %%
# Recolor for better constrast
recolored_image = replace_color(image, lower_red1, upper_red1, white)
recolored_colors = get_colors(recolored_image, 20, "Recolored")

# %%
# Compare original and recolored for protanopia
protanopia_image = simulate_colorblindness(protanopia_simulation_matrix, image_rgb)
protanopia_colors = get_colors(protanopia_image, 20, cb_names[0])

protanopia_image = simulate_colorblindness(protanopia_simulation_matrix, recolored_image)
protanopia_colors = get_colors(protanopia_image, 20, "Recolored " + cb_names[0])

# %%
# Compare original and recolored for tritanopia
tritanopia_image = simulate_colorblindness(tritanopia_simulation_matrix, image_rgb)
tritanopia_colors = get_colors(tritanopia_image, 20, cb_names[2])

tritanopia_image = simulate_colorblindness(tritanopia_simulation_matrix, recolored_image)
tritanopia_colors = get_colors(tritanopia_image, 20, "Recolored " + cb_names[2])
